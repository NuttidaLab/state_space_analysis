# %%
import numpy as np
import pandas as pd

from utils import validate, package_run_data, package_calib_data, circdist, circmedian

# %%
ctiraltable, med, std, ctimetable = package_calib_data(do_clip=False, do_noise_thresh=False)
rtrialtable, rtimetable = package_run_data(med, std, do_clip=False, do_noise_thresh=False)
# Out:
# ...
# Loading data: 100%|██████████| 288/288 [00:01<00:00, 284.96it/s]
# /home/nuttidalab/Documents/rudra/state_space_analysis/utils/package.py:251: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'low' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   resp_df.loc[resp_df["coh"] == -1, "coh"] = "low"
# /home/nuttidalab/Documents/rudra/state_space_analysis/utils/package.py:253: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'focused' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   resp_df.loc[resp_df["att"] == 1, "att"] = "focused"
# ...

# %%
# lets store them up

ctiraltable.to_csv('data_caches/ctiraltable.csv')
np.save('data_caches/med.npy', med)
np.save('data_caches/std.npy', std)
np.save('data_caches/ctimetable.npy', ctimetable)


rtrialtable.to_csv('data_caches/rtrialtable.csv')
np.save('data_caches/rtimetable.npy', rtimetable)

# %%
rtrialtable
# Out:
#        subj  sess  run  trial  target     t_calib        resp    resp_err  \
# 0         1     0    0      0   159.0  145.788047  148.685925    2.897877
# 1         1     0    0      1   123.0  136.060195  129.253756    6.806439
# 2         1     0    0      2    51.0   33.954344  124.965094   91.010750
# 3         1     0    0      3   159.0  145.788047  145.702460    0.085587
# 4         1     0    0      4    15.0   18.896223  144.334808  125.438585
# ...     ...   ...  ...    ...     ...         ...         ...         ...
# 34555    12     3    5    115    51.0   37.827708  161.360749  123.533041
# 34556    12     3    5    116    15.0    3.855904   37.650337   33.794433
# 34557    12     3    5    117   159.0  153.077094   85.831991   67.245104
# 34558    12     3    5    118   123.0  138.552340  152.674066   14.121726
# 34559    12     3    5    119    51.0   37.827708   33.039186    4.788522
#
#             v_err         exp          nn  1sig  2sig  nn_c      att   coh  \
# ...
